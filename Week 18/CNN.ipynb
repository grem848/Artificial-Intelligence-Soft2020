# %% [markdown]
# ## CNN Exercise

# %% [markdown]
# ### 1. Imports

# %%
# !pip uninstall tensorflow -y

# %%
# !pip install tensorflow==1.15
# !pip install tensorflow
# Out:
# Collecting tensorflow==1.15
#   Using cached tensorflow-1.15.0-cp37-cp37m-win_amd64.whl (295.1 MB)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from tensorflow==1.15) (1.18.1)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from tensorflow==1.15) (1.16.1)
# Requirement already satisfied: astor>=0.6.0 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from tensorflow==1.15) (0.8.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from tensorflow==1.15) (1.14.0)
# Requirement already satisfied: keras-applications>=1.0.8 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from tensorflow==1.15) (1.0.8)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from tensorflow==1.15) (0.8.1)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from tensorflow==1.15) (1.15.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from tensorflow==1.15) (1.15.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from tensorflow==1.15) (3.1.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from tensorflow==1.15) (0.34.2)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from tensorflow==1.15) (1.11.2)
# Requirement already satisfied: google-pasta>=0.1.6 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from tensorflow==1.15) (0.1.8)
# Requirement already satisfied: gast==0.2.2 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from tensorflow==1.15) (0.2.2)
# Requirement already satisfied: protobuf>=3.6.1 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from tensorflow==1.15) (3.11.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: h5py in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from keras-applications>=1.0.8->tensorflow==1.15) (2.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (0.16.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.1.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (45.1.0.post20200127)
# Installing collected packages: tensorflow
# Successfully installed tensorflow-1.15.0

# %%
# !pip show tensorflow

# %%
#opencv
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\andreas heick laptop\anaconda3\lib\site-packages (4.0.0.21)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\andreas heick laptop\anaconda3\lib\site-packages (from opencv-python) (1.18.1)

# %%
import cv2
import tensorflow
import tflearn
import os
import numpy as np
from random import shuffle
from tqdm import tqdm
# Out:
# curses is not supported on this machine (please install/reinstall curses for an optimal experience)
# WARNING:tensorflow:From C:\Users\Andreas Heick Laptop\Anaconda3\lib\site-packages\tflearn\helpers\summarizer.py:9: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From C:\Users\Andreas Heick Laptop\Anaconda3\lib\site-packages\tflearn\helpers\trainer.py:25: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From C:\Users\Andreas Heick Laptop\Anaconda3\lib\site-packages\tflearn\collections.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From C:\Users\Andreas Heick Laptop\Anaconda3\lib\site-packages\tflearn\config.py:123: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From C:\Users\Andreas Heick Laptop\Anaconda3\lib\site-packages\tflearn\config.py:129: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From C:\Users\Andreas Heick Laptop\Anaconda3\lib\site-packages\tflearn\config.py:131: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.

# %%
# !python -V
# Out:
# Python 3.7.6

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 1.15.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: c:\users\andreas heick laptop\anaconda3\lib\site-packages
# Requires: termcolor, wheel, wrapt, grpcio, tensorboard, gast, opt-einsum, six, tensorflow-estimator, keras-applications, protobuf, keras-preprocessing, google-pasta, numpy, astor, absl-py
# Required-by:

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Andreas Heick Laptop\\Documents\\VisualStudio Projects\\SOFT - 1 Semester\\Artificial Intelligence\\Week 18'

# %%
TRAIN_DIR = 'train'
IMG_SIZE = 50

# %%
list_train = os.listdir(TRAIN_DIR)

# %%
n = len(list_train)
n
# Out:
# 25000

# %%
list_train[15]
# Out:
# 'cat.1001.jpg'

# %%
# function to get the image file name and create a label for it - one hot encoder
def set_label(file_name):
    label = file_name.split('.')[-3] 
    if label == 'cat': return [1,0]
    elif label == 'dog': return [0,1]

# %%
# prepare train data
def create_train_data(list):
    # empty array, which will contain the train images and their labels
    train_data = []
    
    # for each image file in the train directory:
    for file_name in tqdm(list):
        # convert the file name into label by use of the function above
        label = set_label(file_name)
        
        # extend the file path for this image with the file name
        file_path = os.path.join(TRAIN_DIR, file_name)
        
        # read the image from this file
        img = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
        # img = cv2.imread(path, cv2.IMREAD_UNCHANGED)
        
        # resize the image, so all have same size
        img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))       
        
        # add the image and its label into array 
        # train_data.append([np.array(img), np.array(label)])
        train_data.append([img, label])
        
    shuffle(train_data)
    np.save('train_data.npy', train_data)
    return train_data

# %%
train_data_set = create_train_data(list_train)
# Out:
# 100%|██████████| 25000/25000 [00:46<00:00, 536.78it/s]

# %%
train_data_set
# Out:
# [[array([[15,  3,  3, ...,  6,  6,  6],
#          [12,  5,  3, ...,  6,  6,  6],
#          [12,  6,  5, ...,  6,  6,  6],
#          ...,
#          [11,  7,  2, ..., 10, 15, 13],
#          [13,  9,  5, ...,  6, 14, 12],
#          [12,  7,  5, ...,  1,  1,  2]], dtype=uint8),
#   [1, 0]],
#  [array([[ 50,  49,  48, ...,  54,  59,  63],
#          [ 52,  53,  53, ...,  54,  57,  63],
#          [ 50,  50,  43, ...,  54,  54,  51],
#          ...,
#          [142, 143, 132, ..., 137, 135, 131],
#          [147, 142, 129, ..., 167, 167, 164],
#          [149, 129, 122, ..., 167, 177, 181]], dtype=uint8),
#   [1, 0]],
#  [array([[205, 206, 204, ..., 206, 206, 206],
#          [202, 202, 203, ..., 206, 204, 206],
#          [203, 203, 205, ..., 208, 207, 207],
#          ...,
#          [130, 132, 178, ...,  70,  63,  45],
#          [183, 105, 109, ...,  84,  93,  95],
#          [121,  68,  98, ...,  53,  53,  59]], dtype=uint8),
#   [0, 1]],
#  [array([[ 71,  70,  82, ...,  71,  76,  70],
#          [ 66,  60,  60, ...,  72,  69,  68],
#          [ 70,  58,  53, ...,  71,  65,  65],
#          ...,
#          [ 92,  80, 194, ...,  66,  69,  64],
#          [ 82,  72, 193, ...,  67,  65,  61],
#          [ 86,  70, 192, ...,  65,  67,  61]], dtype=uint8),
#   [0, 1]],
#  [array([[ 87,  73, 123, ...,  91,  87,  82],
#          [ 86,  74, 109, ...,  88,  85,  80],
#          [ 85,  75,  98, ...,  86,  83,  78],
#          ...,
#          [147, 174, 188, ...,  95,  81,  98],
#          [181, 184, 203, ...,  84, 103, 106],
#          [213, 221, 220, ..., 113, 155, 179]], dtype=uint8),
#   [1, 0]],
#  [array([[ 15,  36,  47, ..., 123, 123, 129],
#          [ 18,  28,  45, ..., 125, 124,  28],
#          [ 10,  43,  55, ..., 108,  23,  22],
#          ...,
#          [ 82,  62,  71, ...,  83,  92, 103],
#          [ 65,  70,  70, ...,  66,  75,  83],
#          [ 72,  68,  70, ...,   9,  61,  65]], dtype=uint8),
#   [0, 1]],
#  [array([[ 73,  94, 145, ..., 152, 138, 124],
#          [131, 129, 109, ..., 159, 121, 151],
#          [ 86, 115,  96, ..., 149,  96, 125],
#          ...,
#          [ 92, 117, 116, ..., 139, 173, 157],
#          [ 98, 105,  95, ..., 155, 161, 122],
#          [100, 138,  83, ..., 173, 170, 170]], dtype=uint8),
#   [0, 1]],
#  [array([[245, 250, 233, ..., 239, 237, 244],
#          [241, 245, 244, ..., 244, 239, 242],
#          [246, 240, 235, ..., 241, 234, 241],
#          ...,
#          [205, 182, 167, ..., 176, 187, 165],
#          [177, 183, 184, ..., 187, 204, 205],
#          [196, 154, 204, ..., 183, 177, 195]], dtype=uint8),
#   [0, 1]],
#  [array([[ 69,  68,  54, ...,  18,  26,  22],
#          [ 69,  66,  79, ...,  21,  24,  27],
#          [ 91,  60,  79, ...,  13,  21,  21],
#          ...,
#          [121,  89, 145, ..., 111, 115, 118],
#          [118, 105, 101, ..., 103, 107, 109],
#          [118,  68,  95, ...,  88, 109, 106]], dtype=uint8),
#   [0, 1]],
#  [array([[ 74,  80,  73, ...,  54,  54,  51],
#          [ 77,  77,  83, ...,  54,  54,  57],
#          [ 81,  78,  90, ...,  60,  58,  62],
#          ...,
#          [143, 161, 160, ...,  62,  62,  67],
#          [142, 154, 161, ...,  59,  60,  59],
#          [128, 148, 162, ...,  67,  61,  57]], dtype=uint8),
#   [0, 1]],
#  [array([[ 6,  5, 12, ..., 20, 20, 22],
#          [ 6,  8,  7, ..., 16, 18, 21],
#          [10,  6, 13, ..., 15, 15, 18],
#          ...,
#          [ 9,  3,  7, ..., 20, 19, 16],
#          [13,  3,  6, ..., 19, 17, 15],
#          [15,  5, 11, ..., 19, 18, 13]], dtype=uint8),
#   [1, 0]],
#  [array([[217, 133,  78, ..., 156, 164, 214],
#          [216, 114,  71, ..., 158, 168, 214],
#          [215,  86,  66, ..., 161, 174, 216],
#          ...,
#          [132, 144, 143, ..., 167, 164, 168],
#          [123, 128, 132, ..., 161, 162, 170],
#          [112, 115, 139, ..., 161, 163, 170]], dtype=uint8),
#   [0, 1]],
#  [array([[161, 160, 254, ..., 255, 255, 255],
#          [162, 151, 254, ..., 255, 255, 255],
#          [163, 148, 251, ..., 255, 255, 255],
#          ...,
#          [231, 230, 228, ..., 230, 231, 226],
#          [236, 236, 237, ..., 243, 236, 239],
#          [240, 240, 229, ..., 229, 232, 238]], dtype=uint8),
#   [1, 0]],
#  [array([[251, 252, 255, ..., 144, 155, 141],
#          [255, 255, 255, ..., 165, 166, 155],
#          [255, 255, 254, ..., 174, 170, 158],
#          ...,
#          [165, 174, 175, ...,  40,  33,  17],
#          [163, 168, 168, ...,  90,  60,  85],
#          [144, 148, 157, ...,  40,  85,  53]], dtype=uint8),
#   [1, 0]],
#  [array([[129,  29,  33, ...,   0,   2,   1],
#          [146,  63,  42, ...,   1,   1,   1],
#          [144,  94,  79, ...,   1,   1,   1],
#          ...,
#          [ 24,  40,  42, ...,  26,  23,  13],
#          [ 53,  25,  38, ...,  31,  17,  23],
#          [ 28,  47,  36, ...,  16,  28,  24]], dtype=uint8),
#   [1, 0]],
#  [array([[206, 162, 206, ...,  66,  66,  66],
#          [206, 151, 206, ...,  66,  65,  66],
#          [205, 146, 207, ...,  64,  64,  62],
#          ...,
#          [171, 157, 178, ..., 164, 166, 163],
#          [130, 158, 171, ..., 140, 165, 163],
#          [ 51,  57,  61, ..., 167, 165, 161]], dtype=uint8),
#   [0, 1]],
#  [array([[22, 32, 81, ..., 21, 45, 50],
#          [38, 38, 91, ..., 41, 44, 72],
#          [30, 42, 73, ..., 41, 26, 58],
#          ...,
#          [82, 55, 71, ..., 38, 34, 32],
#          [68, 65, 73, ..., 31, 20, 10],
#          [60, 76, 75, ..., 76, 80, 20]], dtype=uint8),
#   [0, 1]],
#  [array([[ 90, 108, 112, ..., 111, 112, 113],
#          [ 85, 112, 118, ..., 111, 111, 114],
#          [ 79, 115, 118, ..., 111, 112, 113],
#          ...,
#          [194, 183, 177, ..., 185, 188, 185],
#          [177, 181, 187, ..., 201, 196, 203],
#          [192, 203, 201, ..., 206, 202, 191]], dtype=uint8),
#   [1, 0]],
#  [array([[ 77,  94, 107, ...,  56,  59,  51],
#          [168, 161, 103, ...,  48,  56,  36],
#          [144, 217, 103, ...,  21,  21,  20],
#          ...,
#          [ 46,  38, 134, ...,  48,  51,  47],
#          [ 62,  67,  58, ..., 123, 129, 138],
#          [ 56,  46,  41, ..., 153, 188, 194]], dtype=uint8),
#   [0, 1]],
#  [array([[178, 152, 184, ..., 151, 145, 249],
#          [179, 156, 184, ..., 142, 159, 255],
#          [179, 158, 184, ..., 123, 182, 254],
#          ...,
#          [ 59,  56,  55, ...,  61,  66,  68],
#          [ 63,  59,  60, ...,  67,  70,  75],
#          [ 41,  62,  64, ...,  65,  70,  76]], dtype=uint8),
#   [1, 0]],
#  [array([[ 14,  39,  27, ...,  41,  62,  47],
#          [ 10,  45,  31, ...,   6,  53,  68],
#          [ 19,  46,  30, ...,  17,  18,  52],
#          ...,
#          [ 33,  45,  40, ...,  10,  87, 113],
#          [ 37,  34,  39, ...,   6,  30, 113],
#          [ 35,  36,  35, ...,   1,   4,  91]], dtype=uint8),
#   [1, 0]],
#  [array([[191, 191, 193, ..., 216, 216, 214],
#          [190, 192, 191, ..., 216, 216, 215],
#          [187, 189, 189, ..., 216, 216, 213],
#          ...,
#          [ 98, 114,  97, ..., 206, 216, 221],
#          [103, 107, 110, ..., 189, 189, 167],
#          [ 92, 103, 101, ..., 222, 223, 220]], dtype=uint8),
#   [1, 0]],
#  [array([[ 34,  38, 124, ...,  93,  88,  86],
#          [ 40,  40, 136, ..., 100,  91,  86],
#          [ 42,  48, 160, ..., 121, 107,  98],
#          ...,
#          [ 43, 114,  52, ..., 128, 120, 146],
#          [ 42,  99,  52, ..., 124, 121, 104],
#          [ 43,  87,  48, ...,  66,  59,  76]], dtype=uint8),
#   [1, 0]],
#  [array([[202, 191, 162, ...,  20,  21,  23],
#          [200, 190, 159, ...,  23,  24,  21],
#          [195, 188, 161, ...,  27,  27,  27],
#          ...,
#          [168, 171, 165, ..., 164, 210, 178],
#          [174, 170, 179, ..., 166, 183, 165],
#          [178, 174, 194, ..., 212, 162, 194]], dtype=uint8),
#   [0, 1]],
#  [array([[236, 237, 237, ..., 251, 251, 248],
#          [236, 237, 240, ..., 251, 251, 250],
#          [237, 239, 243, ..., 251, 251, 252],
#          ...,
#          [163, 168, 167, ..., 165, 165, 164],
#          [165, 163, 170, ..., 170, 167, 167],
#          [169, 167, 169, ..., 179, 173, 175]], dtype=uint8),
#   [0, 1]],
#  [array([[ 80,  83,  81, ...,  59,  69,  81],
#          [ 76,  81,  81, ...,  69,  78,  88],
#          [ 79,  83,  80, ...,  83,  91, 102],
#          ...,
#          [ 43,  44,  47, ...,  73,  70,  67],
#          [151, 164, 170, ...,  83,  85,  71],
#          [221, 126, 122, ...,  71,  87,  86]], dtype=uint8),
#   [0, 1]],
#  [array([[171, 105,  76, ..., 166, 173, 141],
#          [136, 111,  55, ..., 171, 175, 159],
#          [104, 121,  37, ..., 174, 170, 166],
#          ...,
#          [118, 120, 109, ..., 109, 101, 105],
#          [111, 116, 114, ..., 109, 100, 166],
#          [115, 116, 109, ...,  95, 169, 190]], dtype=uint8),
#   [0, 1]],
#  [array([[ 82,  79,  79, ...,  60,  62,  60],
#          [ 79,  79,  78, ...,  55,  58,  59],
#          [ 80,  82,  84, ...,  56,  60,  59],
#          ...,
#          [106, 109, 107, ...,  81,  85,  83],
#          [103, 102, 109, ...,  74,  81,  85],
#          [102, 104, 105, ...,  80,  74,  78]], dtype=uint8),
#   [0, 1]],
#  [array([[ 83,  79,  85, ...,  63,  59,  57],
#          [ 86,  75,  79, ...,  61,  57,  54],
#          [ 81,  70,  75, ...,  56,  54,  51],
#          ...,
#          [151,  94, 100, ..., 186, 154, 151],
#          [156,  92,  99, ..., 211, 153, 142],
#          [140,  69,  78, ..., 198, 165, 133]], dtype=uint8),
#   [1, 0]],
#  [array([[241, 241, 241, ..., 179, 233, 238],
#          [242, 241, 241, ..., 209, 195, 208],
#          [227, 229, 237, ..., 225, 212, 199],
#          ...,
#          [123,  55,  64, ..., 181, 169, 118],
#          [ 90,  91, 101, ..., 183, 156, 129],
#          [104,  83, 101, ..., 182, 138, 116]], dtype=uint8),
#   [1, 0]],
#  [array([[211, 250, 222, ..., 239, 235, 232],
#          [212, 229, 223, ..., 240, 237, 234],
#          [214, 216, 225, ..., 241, 238, 234],
#          ...,
#          [123, 132, 134, ..., 255, 254, 246],
#          [136, 132, 126, ..., 255, 248, 249],
#          [119, 122, 142, ..., 253, 255, 250]], dtype=uint8),
#   [0, 1]],
#  [array([[117, 104,  98, ..., 152,  98, 108],
#          [ 90,  87,  61, ..., 125, 138, 106],
#          [122, 125,  96, ..., 135, 152, 170],
#          ...,
#          [240, 237, 215, ...,  62, 140, 174],
#          [240, 237, 218, ..., 167, 142,  98],
#          [243, 241, 223, ..., 118, 156, 115]], dtype=uint8),
#   [0, 1]],
#  [array([[162, 156, 163, ..., 155, 156, 154],
#          [159, 150, 153, ..., 153, 156, 156],
#          [157, 148, 154, ...,  61,  31,  38],
#          ...,
#          [ 57, 123,  89, ...,  19,  86, 127],
#          [120,  87,  82, ...,  70,  68,  82],
#          [137, 130, 119, ...,  97,  66, 149]], dtype=uint8),
#   [0, 1]],
#  [array([[252, 246, 250, ..., 124, 119, 113],
#          [252, 251, 246, ..., 135, 129, 124],
#          [252, 246, 247, ..., 143, 140, 133],
#          ...,
#          [ 85, 165, 146, ..., 115, 103,  89],
#          [ 84, 133, 145, ..., 120,  96,  89],
#          [ 83,  94, 157, ..., 100,  86,  69]], dtype=uint8),
#   [1, 0]],
#  [array([[131, 141, 131, ..., 155, 136,  45],
#          [126, 132, 132, ..., 125, 146, 149],
#          [124, 123, 139, ..., 128, 111, 123],
#          ...,
#          [147,  83,  55, ...,  28,  90,  52],
#          [203, 106,  55, ...,  68,  37,  53],
#          [157, 179,  71, ...,  71,  28,  48]], dtype=uint8),
#   [0, 1]],
#  [array([[ 49,  97,  97, ...,  75,  92, 107],
#          [ 68, 102,  86, ..., 101,  77,  27],
#          [ 67, 104,  45, ...,  34, 109, 107],
#          ...,
#          [ 73,  23,  84, ...,   7,   3,   6],
#          [ 67,  27,  84, ...,   5,   2,   6],
#          [ 63,  36,  78, ...,   5,   2,   4]], dtype=uint8),
#   [1, 0]],
#  [array([[162, 254, 255, ..., 255, 255, 255],
#          [162, 254, 255, ..., 255, 255, 255],
#          [163, 255, 255, ..., 255, 255, 255],
#          ...,
#          [227, 225, 225, ..., 125, 109, 116],
#          [227, 221, 219, ..., 116, 120, 117],
#          [229, 226, 216, ..., 120, 119, 117]], dtype=uint8),
#   [1, 0]],
#  [array([[151, 112,  84, ..., 149, 160, 144],
#          [178,  85, 216, ..., 170, 176, 175],
#          [ 95, 178, 165, ...,  54,  49,  43],
#          ...,
#          [ 16,  20,  31, ...,  47,  42,  51],
#          [ 17,  25,  98, ...,  52,  45,  49],
#          [ 21,  25, 124, ...,  51,  42,  53]], dtype=uint8),
#   [0, 1]],
#  [array([[ 2,  7, 11, ...,  1,  0,  1],
#          [ 9,  6,  8, ...,  1,  2,  0],
#          [12,  9,  9, ...,  2,  2,  0],
#          ...,
#          [66, 60, 67, ..., 51, 68, 54],
#          [66, 68, 68, ..., 60, 73, 63],
#          [64, 67, 57, ..., 65, 51, 56]], dtype=uint8),
#   [1, 0]],
#  [array([[37, 38, 39, ..., 48, 10, 14],
#          [38, 40, 43, ..., 28,  7, 10],
#          [40, 40, 43, ..., 27,  9, 10],
#          ...,
#          [17, 15, 19, ..., 58, 62, 55],
#          [15, 17, 19, ..., 65, 64, 55],
#          [16, 15, 20, ..., 65, 56, 68]], dtype=uint8),
#   [0, 1]],
#  [array([[158, 138, 141, ..., 200,  69,  67],
#          [143, 133, 131, ..., 198,  72,  68],
#          [ 89, 143, 135, ..., 200,  71,  70],
#          ...,
#          [155, 159, 163, ..., 121, 114, 107],
#          [169, 160, 156, ..., 122, 118, 110],
#          [188, 158, 215, ..., 118, 112, 109]], dtype=uint8),
#   [1, 0]],
#  [array([[179, 176, 193, ..., 110, 152, 109],
#          [142, 160, 215, ..., 148, 130, 113],
#          [143, 178, 124, ..., 127, 121, 117],
#          ...,
#          [123,  85,  91, ...,  99,  87,  67],
#          [ 62,  66, 143, ...,  84,  92,  40],
#          [103, 104, 142, ...,  84,  37,  62]], dtype=uint8),
#   [0, 1]],
#  [array([[13,  8, 14, ..., 75, 71, 59],
#          [10, 11, 12, ..., 76, 95, 85],
#          [13, 12, 11, ..., 51, 71, 63],
#          ...,
#          [54, 50, 50, ..., 49, 54, 60],
#          [39, 48, 43, ..., 41, 41, 43],
#          [39, 40, 42, ..., 49, 46, 46]], dtype=uint8),
#   [0, 1]],
#  [array([[  0,   7,   1, ...,   1,   2,   3],
#          [  1, 144, 137, ..., 149, 153,   1],
#          [  1, 139, 135, ..., 153, 165,   5],
#          ...,
#          [  0,  97,  91, ..., 111, 114,   0],
#          [  0,  65,  57, ..., 122, 126,   0],
#          [  0,   1,   2, ...,   0,   2,   2]], dtype=uint8),
#   [1, 0]],
#  [array([[ 69, 101, 138, ...,  37,  52,  53],
#          [ 72, 106, 142, ...,  34,  40,  43],
#          [ 76,  81, 118, ...,  39,  39,  54],
#          ...,
#          [ 63,  68,  67, ...,  60,  76,  81],
#          [ 67,  73,  68, ...,  65,  74,  66],
#          [ 63,  68,  66, ...,  60,  66,  61]], dtype=uint8),
#   [0, 1]],
#  [array([[212, 225, 175, ..., 165, 134, 105],
#          [114, 129, 150, ...,  90, 128,  55],
#          [173, 167, 187, ..., 184, 186, 240],
#          ...,
#          [192, 167, 222, ..., 124, 107, 164],
#          [194, 181, 123, ..., 157, 196, 168],
#          [165, 132, 144, ..., 193, 144, 111]], dtype=uint8),
#   [0, 1]],
#  [array([[116,  71,  60, ..., 144, 144, 136],
#          [ 66,  56,  57, ..., 153, 151, 153],
#          [ 58,  56,  66, ..., 150, 149, 147],
#          ...,
#          [168, 172, 160, ..., 151, 151, 157],
#          [156, 164, 165, ..., 155, 159, 160],
#          [167, 172, 169, ..., 156, 153, 165]], dtype=uint8),
#   [0, 1]],
#  [array([[114, 125, 148, ...,  99,  90,  85],
#          [128, 124, 144, ..., 113, 108,  98],
#          [128, 133, 143, ..., 108, 100, 118],
#          ...,
#          [ 82,  98,  99, ..., 114,  92,  86],
#          [ 86,  92,  98, ...,  92,  90,  93],
#          [ 83,  98,  93, ...,  80,  67,  70]], dtype=uint8),
#   [0, 1]],
#  [array([[253, 246, 249, ..., 234,  72, 177],
#          [254, 246, 243, ..., 243,  90, 176],
#          [253, 250, 215, ...,  51, 146, 172],
#          ...,
#          [ 78,  83,  90, ...,  55,  55,  57],
#          [ 73,  81,  85, ...,  54,  56,  56],
#          [ 66,  74,  81, ...,  52,  51,  53]], dtype=uint8),
#   [1, 0]],
#  [array([[252, 253, 250, ...,  92, 128, 138],
#          [255, 254, 250, ...,  44,  72,  97],
#          [254, 253, 250, ...,  16,  22,  41],
#          ...,
#          [ 35,  43,  39, ..., 165, 167, 159],
#          [ 28,  32,  35, ..., 164, 158, 153],
#          [ 33,  32,  29, ..., 161, 163, 155]], dtype=uint8),
#   [0, 1]],
#  [array([[180, 158, 161, ..., 176, 173, 168],
#          [178, 172, 159, ..., 164, 180, 174],
#          [161, 185, 157, ..., 170, 165, 185],
#          ...,
#          [146, 142, 127, ..., 146, 132, 128],
#          [139, 154, 143, ..., 147, 138, 130],
#          [158, 149, 142, ..., 154, 159, 162]], dtype=uint8),
#   [1, 0]],
#  [array([[114, 105, 107, ..., 158, 173, 166],
#          [116, 110, 110, ..., 149, 150, 161],
#          [107, 117, 111, ..., 160, 155, 162],
#          ...,
#          [ 85,  85,  82, ..., 139, 136, 133],
#          [ 70,  85,  75, ..., 139, 137, 131],
#          [ 86,  78,  70, ..., 138, 134, 128]], dtype=uint8),
#   [0, 1]],
#  [array([[117, 120, 115, ..., 134, 137, 132],
#          [122, 121, 129, ..., 127, 126, 124],
#          [127, 126, 128, ..., 127, 129, 128],
#          ...,
#          [216, 221, 231, ..., 192, 214, 218],
#          [221, 214, 225, ..., 207, 208, 214],
#          [220, 226, 223, ..., 191, 174, 179]], dtype=uint8),
#   [1, 0]],
#  [array([[ 27,  14,  10, ...,  11,  17,  15],
#          [ 31,  16,  18, ...,  15,  15,  14],
#          [ 28,  32,  19, ...,  18,  17,  16],
#          ...,
#          [ 83,  81,  73, ...,  96, 153, 167],
#          [122,  75, 103, ..., 129, 118, 152],
#          [ 77, 104,  63, ..., 139, 137, 112]], dtype=uint8),
#   [1, 0]],
#  [array([[134, 134, 128, ..., 181, 164, 168],
#          [143, 140, 151, ..., 179, 167, 173],
#          [149, 175, 183, ..., 177, 170, 177],
#          ...,
#          [155, 155, 156, ..., 192, 200, 188],
#          [156, 157, 158, ..., 193, 200, 205],
#          [157, 158, 159, ..., 199, 195, 202]], dtype=uint8),
#   [1, 0]],
#  [array([[ 95, 105,  91, ...,  76,  91,  92],
#          [103,  99,  93, ...,  75,  85,  81],
#          [ 99,  89,  93, ...,  81,  83,  75],
#          ...,
#          [ 82,  80,  85, ..., 126, 106, 104],
#          [ 81,  83,  87, ..., 113,  72,  94],
#          [ 86,  89,  84, ..., 112,  76, 100]], dtype=uint8),
#   [0, 1]],
#  [array([[ 24,  23,  24, ...,  60,  53,  55],
#          [ 16,  15,  21, ...,  47,  42,  61],
#          [ 20,  22,  64, ...,  50,  47,  68],
#          ...,
#          [140, 146, 147, ..., 148, 162, 161],
#          [138, 151, 162, ..., 147, 161, 166],
#          [145, 136, 139, ..., 146, 150, 153]], dtype=uint8),
#   [1, 0]],
#  [array([[  9,  33,  45, ...,  13,   9,  19],
#          [ 43,  48,  31, ...,  18,  15,  21],
#          [ 42,  44,  11, ...,  24,  15,  17],
#          ...,
#          [ 73,  82,  93, ...,  95,  99,  97],
#          [ 79,  87,  91, ..., 100, 103, 104],
#          [ 63,  62,  61, ..., 116, 111, 100]], dtype=uint8),
#   [0, 1]],
#  [array([[117, 118, 119, ..., 110, 111, 110],
#          [118, 120, 126, ..., 110, 111, 108],
#          [122, 129, 132, ..., 112, 113, 113],
#          ...,
#          [  6,   5,   6, ...,  16,  15,  14],
#          [  4,   4,   7, ...,  15,  15,  19],
#          [  4,   3,   8, ...,  17,  18,  13]], dtype=uint8),
#   [1, 0]],
#  [array([[101, 101,  82, ..., 128, 103, 125],
#          [117,  92, 101, ..., 105, 116, 142],
#          [105, 110, 100, ..., 126, 132, 136],
#          ...,
#          [195, 244, 225, ..., 241, 241, 223],
#          [190, 241, 249, ..., 205, 255, 246],
#          [233, 253, 152, ..., 255, 255, 219]], dtype=uint8),
#   [0, 1]],
#  [array([[103, 101,  93, ...,  27, 113, 149],
#          [ 95, 105, 105, ...,  28,  31,  24],
#          [107, 123,  99, ...,  30,  30,  67],
#          ...,
#          [ 60, 134,  82, ...,  41,  39,  40],
#          [183,  82, 185, ..., 106, 104,  85],
#          [100,  47,  98, ..., 253, 252, 253]], dtype=uint8),
#   [1, 0]],
#  [array([[ 60,  60,  75, ..., 103, 112, 106],
#          [ 63,  51,  70, ..., 107, 118, 115],
#          [ 68,  94,  80, ..., 111, 116, 116],
#          ...,
#          [148, 198, 192, ..., 132, 117, 113],
#          [136, 166, 168, ..., 133, 123, 118],
#          [144, 174, 186, ..., 127, 125, 112]], dtype=uint8),
#   [1, 0]],
#  [array([[162, 177, 179, ..., 180, 170, 163],
#          [172, 177, 176, ..., 183, 171, 164],
#          [178, 185, 178, ..., 183, 173, 165],
#          ...,
#          [201, 194, 197, ..., 226, 223, 231],
#          [212, 198, 190, ..., 228, 225, 229],
#          [210, 209, 190, ..., 228, 227, 224]], dtype=uint8),
#   [1, 0]],
#  [array([[162, 165, 168, ..., 167, 162, 159],
#          [165, 169, 171, ..., 172, 166, 163],
#          [169, 170, 176, ..., 176, 172, 169],
#          ...,
#          [165, 169, 174, ..., 172, 173, 165],
#          [158, 163, 167, ..., 170, 167, 159],
#          [147, 153, 157, ..., 161, 157, 150]], dtype=uint8),
#   [0, 1]],
#  [array([[175, 177, 183, ..., 209, 235, 200],
#          [176, 157, 126, ..., 178, 199, 194],
#          [207, 201, 216, ..., 142, 136, 144],
#          ...,
#          [201, 202, 195, ..., 132, 137, 158],
#          [231, 232, 191, ..., 174, 106,  81],
#          [176, 202, 188, ..., 110, 185, 159]], dtype=uint8),
#   [0, 1]],
#  [array([[176, 192, 158, ..., 211, 223, 245],
#          [173, 222, 178, ..., 235, 139, 195],
#          [209, 161, 212, ..., 236, 245, 206],
#          ...,
#          [105,  60,  40, ...,  48,  44,  71],
#          [ 44,  41,  51, ...,  47,  43,  67],
#          [ 52,  36,  30, ...,  49,  44,  36]], dtype=uint8),
#   [0, 1]],
#  [array([[ 25,  81,  80, ...,  85,  85,  86],
#          [ 32,  29,  84, ...,  90,  87,  89],
#          [ 29,  32,  56, ...,  92,  97,  90],
#          ...,
#          [254, 254, 254, ..., 254, 254, 254],
#          [254, 254, 254, ..., 254, 254, 254],
#          [254, 254, 254, ..., 254, 254, 254]], dtype=uint8),
#   [0, 1]],
#  [array([[ 99, 238, 239, ..., 207, 209, 172],
#          [ 81, 239, 243, ..., 211, 209, 123],
#          [ 79, 240, 243, ..., 213, 212,  99],
#          ...,
#          [187, 196, 189, ..., 105, 139, 137],
#          [185, 191, 196, ..., 166, 157, 147],
#          [191, 189, 176, ..., 216, 172, 147]], dtype=uint8),
#   [1, 0]],
#  [array([[ 27,  15,  22, ..., 104,  82,  81],
#          [ 23,  26,  13, ...,  86,  98, 108],
#          [ 26,  26,  22, ...,  63,  62,  70],
#          ...,
#          [ 85,  87,  87, ...,  71,  64,  62],
#          [ 90,  85,  97, ...,  68,  63,  67],
#          [ 80,  85,  86, ...,  68,  69,  68]], dtype=uint8),
#   [0, 1]],
#  [array([[ 76,  78,  76, ...,  76,  74,  70],
#          [ 79,  78,  82, ...,  78,  76,  74],
#          [ 83,  83,  71, ...,  80,  80,  76],
#          ...,
#          [109,  92,  80, ..., 149, 149, 147],
#          [125, 163, 159, ..., 164, 156, 145],
#          [165, 173, 180, ..., 135, 136, 134]], dtype=uint8),
#   [0, 1]],
#  [array([[184, 180, 202, ..., 147, 140, 134],
#          [216, 209, 201, ..., 150, 145, 142],
#          [224, 217, 208, ..., 152, 152, 148],
#          ...,
#          [  6,   6,   4, ...,  27,  24,  24],
#          [  6,   6,   6, ...,  23,  25,  21],
#          [  6,   6,  18, ...,  16,  26,  21]], dtype=uint8),
#   [0, 1]],
#  [array([[ 75,  77,  75, ...,  72,  79,  92],
#          [ 77, 133, 152, ...,  80,  85,  79],
#          [124, 142, 148, ...,  72,  80,  86],
#          ...,
#          [143, 131, 149, ..., 141, 152, 161],
#          [144, 141, 145, ..., 160, 157, 154],
#          [145, 140, 141, ..., 137, 138, 157]], dtype=uint8),
#   [0, 1]],
#  [array([[186, 178, 171, ...,  92,  90,  90],
#          [196, 181, 174, ...,  94,  93,  92],
#          [199, 193, 182, ...,  96,  93,  94],
#          ...,
#          [ 64,  64,  60, ...,  49,  43,  43],
#          [ 62,  65,  70, ...,  53,  50,  48],
#          [ 50,  58,  54, ...,  67,  60,  55]], dtype=uint8),
#   [1, 0]],
#  [array([[ 33,  32,  37, ...,  19,  20,  15],
#          [ 39,  34,  33, ...,  22,  22,  23],
#          [ 39,  40,  41, ...,  22,  25,  22],
#          ...,
#          [131, 127, 119, ...,  69,  67,  57],
#          [120, 120, 121, ...,  68,  64,  56],
#          [117, 129, 124, ...,  56,  72,  65]], dtype=uint8),
#   [0, 1]],
#  [array([[  3,   2,   1, ...,   1,  12,   1],
#          [  3,   5,   4, ...,   1,   1,   1],
#          [ 19,  16,   7, ...,   1,   0,   1],
#          ...,
#          [ 32,  21,   6, ...,  30,  33,  26],
#          [ 59,  91, 152, ...,   2,   1,   4],
#          [  3,   2,   1, ...,   1,   0,   5]], dtype=uint8),
#   [1, 0]],
#  [array([[  5,   5,   9, ...,  52,  48,  47],
#          [  7,   8,  11, ...,  54,  50,  47],
#          [  7,   9,  10, ...,  53,  48,  47],
#          ...,
#          [141, 143, 141, ..., 103, 120, 141],
#          [135, 136, 137, ...,  87, 149, 110],
#          [144, 152, 135, ..., 163, 117, 112]], dtype=uint8),
#   [0, 1]],
#  [array([[254, 254, 254, ..., 205, 204, 197],
#          [254, 254, 254, ..., 187, 175, 186],
#          [254, 251, 249, ...,  82, 205, 165],
#          ...,
#          [152, 192, 153, ..., 109,  82,  92],
#          [116, 163, 147, ...,  82,  97, 118],
#          [159, 155, 143, ..., 106,  93,  83]], dtype=uint8),
#   [0, 1]],
#  [array([[ 72,  73,  69, ...,  36,  24,  15],
#          [ 77,  72,  69, ...,  46,  36,  19],
#          [ 70,  76,  68, ...,  46,  33,  15],
#          ...,
#          [ 61,  68,  66, ..., 136, 131, 149],
#          [ 75,  71,  66, ..., 147, 157, 136],
#          [ 78,  68,  85, ..., 137, 158, 158]], dtype=uint8),
#   [1, 0]],
#  [array([[122, 135, 115, ..., 192, 235, 252],
#          [127, 136, 129, ..., 191, 217, 225],
#          [117, 133, 124, ..., 192, 204, 202],
#          ...,
#          [ 86,  78,  83, ...,  45,  45,  47],
#          [ 80,  82,  72, ...,  51,  51,  52],
#          [ 76,  79,  76, ..., 153,  61,  62]], dtype=uint8),
#   [0, 1]],
#  [array([[254, 253, 251, ..., 254, 246, 255],
#          [254, 122, 112, ...,  91, 120, 255],
#          [253, 123, 114, ..., 101, 127, 255],
#          ...,
#          [254, 168, 165, ..., 178, 195, 255],
#          [254, 168, 163, ..., 176, 195, 255],
#          [254, 254, 255, ..., 254, 253, 255]], dtype=uint8),
#   [0, 1]],
#  [array([[ 97, 103,  93, ..., 127, 111, 120],
#          [127, 111, 115, ..., 126, 115, 116],
#          [122,  95, 102, ..., 109, 132, 119],
#          ...,
#          [176, 178, 165, ..., 184, 197, 200],
#          [159, 200, 159, ..., 212, 220, 174],
#          [160, 177, 166, ..., 219, 214, 232]], dtype=uint8),
#   [0, 1]],
#  [array([[ 75,  88,  73, ..., 108, 104, 110],
#          [ 79,  92,  90, ..., 122, 111, 111],
#          [ 77,  98,  94, ..., 125, 122, 115],
#          ...,
#          [177, 183, 157, ..., 173, 176, 177],
#          [170, 158, 126, ..., 175, 179, 177],
#          [137, 118, 100, ..., 174, 176, 177]], dtype=uint8),
#   [1, 0]],
#  [array([[104, 105, 103, ...,  71,  70,  71],
#          [106, 105, 102, ...,  71,  72,  71],
#          [105, 105, 103, ...,  71,  67,  70],
#          ...,
#          [161, 180, 178, ...,  73, 107,  99],
#          [163, 171, 168, ...,  69,  70, 108],
#          [195, 193, 191, ...,  75,  79,  80]], dtype=uint8),
#   [1, 0]],
#  [array([[ 84,  78,  75, ...,  67,  62,  63],
#          [ 70,  68,  75, ...,  58,  67,  62],
#          [ 89,  72,  73, ...,  68,  71,  78],
#          ...,
#          [134, 150, 166, ..., 145, 157, 145],
#          [156, 167, 163, ..., 162, 137, 164],
#          [142, 167, 152, ..., 182, 168, 172]], dtype=uint8),
#   [1, 0]],
#  [array([[13, 14, 14, ...,  1,  1,  1],
#          [14, 14, 13, ...,  1,  1,  1],
#          [14, 16, 16, ...,  1,  1,  1],
#          ...,
#          [29, 24, 37, ...,  4,  2,  1],
#          [25, 22, 36, ...,  1,  1,  1],
#          [31, 19, 35, ...,  2,  1,  1]], dtype=uint8),
#   [0, 1]],
#  [array([[ 77, 106,  83, ...,  20,  20,  19],
#          [ 96, 110,  93, ...,  21,  20,  20],
#          [ 82,  70, 120, ...,  29,  32,  32],
#          ...,
#          [197, 164, 164, ..., 166, 162, 155],
#          [156, 167, 162, ..., 163, 166, 157],
#          [149, 173, 161, ..., 154, 154, 151]], dtype=uint8),
#   [0, 1]],
#  [array([[ 30,  33,  27, ...,  49,  50,  51],
#          [ 22,  26,  23, ...,  44,  45,  47],
#          [ 47,  43,  33, ...,  33,  25,  23],
#          ...,
#          [170, 156, 166, ..., 182, 181, 178],
#          [194, 188, 185, ..., 183, 190, 191],
#          [109,  59,  61, ..., 194, 195, 192]], dtype=uint8),
#   [0, 1]],
#  [array([[122, 126, 126, ...,  39,  38,  52],
#          [146, 151,  88, ...,  30,  54, 173],
#          [ 92,  92,  88, ..., 171,  55, 245],
#          ...,
#          [ 63,  61,  59, ...,  66,  62,  50],
#          [ 64,  64,  55, ...,  65,  64,  72],
#          [ 63,  59,  94, ...,  67,  37,  63]], dtype=uint8),
#   [0, 1]],
#  [array([[ 82, 127, 103, ..., 109,  97, 111],
#          [150,  90, 162, ..., 103,  98, 105],
#          [ 78, 114,  53, ..., 111, 110, 113],
#          ...,
#          [135, 123, 129, ..., 136, 122, 123],
#          [115,  85, 134, ..., 138,  95, 121],
#          [ 84, 111,  87, ..., 168, 145,  80]], dtype=uint8),
#   [0, 1]],
#  [array([[ 19,  16,  10, ...,  27,  24,  20],
#          [ 74,  11,   8, ...,  30,  27,  11],
#          [ 48,   4,   9, ...,  25,  20,  21],
#          ...,
#          [ 51,  53, 101, ...,  90,  89,  97],
#          [ 56, 101,  71, ...,  96,  94,  95],
#          [ 98,  45,  91, ...,  95,  95, 102]], dtype=uint8),
#   [0, 1]],
#  [array([[ 20,  17,  27, ...,  60,  84,  85],
#          [ 47,  29,  13, ...,  63, 101,  93],
#          [ 97, 112, 107, ...,  77, 107, 106],
#          ...,
#          [ 59,  64,  36, ...,  63,  67,  88],
#          [ 58,  98,  76, ...,  70,  83,  81],
#          [ 71,  92,  76, ...,  75,  76,  65]], dtype=uint8),
#   [0, 1]],
#  [array([[214, 146, 165, ...,  76,  80, 146],
#          [178, 154, 168, ...,  63,  76, 149],
#          [143, 153, 169, ...,  33,  68,  85],
#          ...,
#          [ 59,  55,  98, ...,  28,  30,  32],
#          [ 58,  58,  97, ...,  28,  30,  44],
#          [ 64,  57,  63, ...,  29,  35,  45]], dtype=uint8),
#   [1, 0]],
#  [array([[102, 103,  98, ..., 103, 110,  60],
#          [103, 104, 104, ...,  84,  98,  72],
#          [101, 102, 101, ...,  75,  84,  71],
#          ...,
#          [114, 114, 121, ...,  85,  89,  88],
#          [116, 123, 117, ...,  89,  86,  91],
#          [119, 116, 120, ...,  83,  83,  83]], dtype=uint8),
#   [1, 0]],
#  [array([[254, 254, 255, ..., 255, 255, 255],
#          [183, 181, 185, ...,  84,  12,  14],
#          [177, 180, 201, ...,  47,  10,  11],
#          ...,
#          [107, 107, 105, ..., 143,  96, 115],
#          [ 91,  91,  91, ..., 114, 123, 137],
#          [ 88,  86,  78, ..., 118, 120, 125]], dtype=uint8),
#   [0, 1]],
#  [array([[ 51,  34,  55, ..., 179, 159, 168],
#          [ 42,  32,  51, ..., 176, 170, 173],
#          [ 38,  31,  62, ..., 177, 176, 182],
#          ...,
#          [ 39, 107, 126, ..., 135, 119,  95],
#          [114,  72,  80, ..., 128,  82,  79],
#          [ 57,  88,  80, ..., 119,  86,  78]], dtype=uint8),
#   [0, 1]],
#  [array([[ 60,  53,  52, ...,  14,  17,  22],
#          [ 52,  44,  46, ...,  11,  20,  20],
#          [ 45,  40,  36, ...,  13,  18,  21],
#          ...,
#          [ 57,  49,  35, ..., 151, 162, 169],
#          [ 35,  40,  55, ..., 116, 114, 171],
#          [ 39,  58,  40, ...,  94, 153, 154]], dtype=uint8),
#   [0, 1]],
#  [array([[ 94, 144, 183, ..., 200, 197, 191],
#          [ 99, 174, 189, ..., 191, 195, 192],
#          [133, 183, 174, ..., 193, 191, 190],
#          ...,
#          [ 93,  80,  76, ..., 126, 120, 115],
#          [ 98,  93,  74, ..., 121, 113, 113],
#          [110,  98,  59, ..., 118, 114, 115]], dtype=uint8),
#   [1, 0]],
#  [array([[ 71,  73,  80, ...,  78,  73,  72],
#          [ 63,  74,  73, ...,  78,  70,  68],
#          [ 66,  65,  71, ...,  75,  71,  66],
#          ...,
#          [152, 141, 147, ...,  60,  63,  81],
#          [143, 143, 150, ...,  70,  68,  75],
#          [146, 157, 147, ...,  76,  85,  89]], dtype=uint8),
#   [1, 0]],
#  [array([[206, 206, 212, ..., 204, 206, 210],
#          [218, 209, 213, ..., 212, 208, 213],
#          [213, 215, 221, ..., 218, 215, 208],
#          ...,
#          [217, 222, 219, ..., 221, 226, 215],
#          [225, 222, 216, ..., 220, 220, 218],
#          [226, 222, 219, ..., 221, 213, 219]], dtype=uint8),
#   [1, 0]],
#  [array([[ 31,  36,  43, ..., 101,  99,  97],
#          [ 18,  21,  33, ..., 103, 103,  98],
#          [ 23,  18,  27, ...,  73,  74,  69],
#          ...,
#          [ 83,  80,  79, ...,  79,  78,  60],
#          [ 78,  81,  82, ...,  78,  75,  75],
#          [ 78,  77,  98, ...,  76,  74,  74]], dtype=uint8),
#   [1, 0]],
#  [array([[102, 110, 105, ..., 137, 134, 125],
#          [103, 101, 105, ..., 140, 137, 129],
#          [104, 109, 108, ..., 141, 140, 139],
#          ...,
#          [122, 133, 228, ..., 209, 206, 212],
#          [126, 199, 211, ..., 211, 227, 212],
#          [128, 218, 206, ..., 214, 205, 206]], dtype=uint8),
#   [1, 0]],
#  [array([[ 39,  32,  36, ..., 199, 197, 198],
#          [ 47,  44,  39, ..., 194, 190, 189],
#          [ 49,  50,  40, ..., 196, 199, 203],
#          ...,
#          [121, 153, 127, ..., 188, 162, 183],
#          [123, 110, 106, ..., 176, 181, 165],
#          [145, 155, 123, ..., 177, 180, 192]], dtype=uint8),
#   [0, 1]],
#  [array([[193, 202, 211, ...,  82,  87,  80],
#          [195, 205, 213, ...,  84,  83,  82],
#          [197, 212, 213, ...,  83,  83,  84],
#          ...,
#          [ 95, 101, 111, ...,  98,  94,  94],
#          [ 94,  92,  97, ..., 133, 119, 100],
#          [ 97,  95,  96, ..., 138, 104,  98]], dtype=uint8),
#   [0, 1]],
#  [array([[161,  62, 130, ..., 109, 105, 109],
#          [166,  59, 131, ..., 108, 109, 107],
#          [165,  62, 134, ..., 111, 108, 105],
#          ...,
#          [136, 135, 133, ...,  43,  45,  43],
#          [135, 134, 134, ...,  44,  42,  41],
#          [133, 136, 136, ...,  41,  41,  46]], dtype=uint8),
#   [1, 0]],
#  [array([[129, 100, 151, ..., 175, 119, 105],
#          [135, 131, 131, ..., 166, 148, 146],
#          [ 62, 133, 139, ..., 160, 139, 167],
#          ...,
#          [ 35,  37,  44, ..., 156, 126, 161],
#          [ 45,  35,  59, ..., 116, 120, 151],
#          [ 39,  40,  47, ..., 102, 152, 101]], dtype=uint8),
#   [0, 1]],
#  [array([[205, 205, 204, ..., 212, 212, 212],
#          [212, 212, 211, ..., 212, 212, 212],
#          [212, 212, 212, ..., 212, 212, 212],
#          ...,
#          [ 19,  30,  44, ..., 111, 120, 117],
#          [ 15,  23,  34, ..., 240, 178, 163],
#          [ 41,  51,  51, ..., 241, 253, 251]], dtype=uint8),
#   [1, 0]],
#  [array([[51, 48, 48, ...,  6,  6,  7],
#          [71, 72, 64, ...,  6,  6,  7],
#          [59, 71, 81, ...,  7,  7,  8],
#          ...,
#          [16, 33, 32, ..., 44, 37, 39],
#          [60, 35, 33, ..., 40, 38, 40],
#          [98, 61, 24, ...,  4,  4, 42]], dtype=uint8),
#   [1, 0]],
#  [array([[ 54,  54,  53, ...,  81,  82,  77],
#          [ 53,  54,  53, ...,  81,  82,  75],
#          [ 54,  56,  55, ...,  82,  84,  73],
#          ...,
#          [130, 118, 164, ...,  56,  49,  66],
#          [119, 165, 156, ...,  48,  30, 137],
#          [128, 148, 150, ...,  96,  32, 151]], dtype=uint8),
#   [1, 0]],
#  [array([[192,  53, 175, ..., 142, 130, 115],
#          [181, 169, 177, ..., 148, 139, 116],
#          [187, 163, 186, ..., 152, 145, 116],
#          ...,
#          [219, 214, 215, ..., 216, 207, 204],
#          [206, 219, 229, ..., 218, 218, 200],
#          [217, 218, 228, ..., 213, 207, 195]], dtype=uint8),
#   [1, 0]],
#  [array([[ 14,  17,  17, ...,  20, 103,  67],
#          [ 18,  14,  12, ...,  82,  34,  29],
#          [ 15,  16,  15, ...,  18,  16,  23],
#          ...,
#          [129, 154, 144, ..., 167, 164, 151],
#          [170, 154, 151, ..., 156, 136, 140],
#          [164, 155, 139, ..., 150, 121, 113]], dtype=uint8),
#   [1, 0]],
#  [array([[ 72,  73,  71, ...,  44,  55,  52],
#          [ 69,  68,  74, ...,  49,  69,  94],
#          [ 75,  73,  79, ..., 145, 110, 126],
#          ...,
#          [ 38,  28, 236, ..., 164, 128, 209],
#          [ 57,  36, 245, ..., 199, 201, 156],
#          [ 89,  30, 231, ..., 210, 129, 198]], dtype=uint8),
#   [1, 0]],
#  [array([[141, 145, 142, ..., 147, 146, 147],
#          [142, 143, 142, ..., 147, 150, 147],
#          [140, 147, 145, ..., 150, 148, 146],
#          ...,
#          [147, 160, 122, ..., 163, 168, 163],
#          [167, 163, 140, ...,  94, 151, 159],
#          [158, 162, 114, ...,  69,  67,  73]], dtype=uint8),
#   [1, 0]],
#  [array([[ 44,  87,  92, ..., 160, 204, 186],
#          [ 42,  67,  69, ..., 188, 184, 197],
#          [ 35,  61,  53, ..., 194, 175, 182],
#          ...,
#          [135, 140, 143, ..., 188, 183, 112],
#          [131, 132, 134, ..., 184, 195, 188],
#          [125, 133, 138, ..., 190, 190, 189]], dtype=uint8),
#   [1, 0]],
#  [array([[189, 191, 193, ..., 191, 189, 188],
#          [185, 189, 191, ..., 190, 190, 187],
#          [182, 187, 189, ..., 193, 187, 186],
#          ...,
#          [169, 184, 188, ..., 163, 170, 170],
#          [179, 178, 190, ..., 208, 210, 208],
#          [156, 174, 167, ..., 211, 212, 211]], dtype=uint8),
#   [1, 0]],
#  [array([[ 62,  62,  62, ...,  65,  70,  66],
#          [ 62,  62,  62, ...,  64,  64,  62],
#          [ 63,  63,  63, ...,  67,  63,  64],
#          ...,
#          [ 84,  96,  97, ...,  77,  70,  82],
#          [ 86,  86,  70, ...,  97,  77,  81],
#          [ 82,  85,  85, ..., 146,  78,  83]], dtype=uint8),
#   [1, 0]],
#  [array([[254, 254, 254, ..., 254, 254, 254],
#          [254, 254, 254, ..., 254, 254, 254],
#          [254, 254, 249, ..., 252, 252, 252],
#          ...,
#          [174, 161, 225, ..., 235, 214, 201],
#          [192, 212, 236, ..., 218, 181, 187],
#          [223, 211, 165, ..., 240, 237, 229]], dtype=uint8),
#   [1, 0]],
#  [array([[ 78,  76,  72, ..., 134, 142, 137],
#          [ 71,  72,  78, ..., 118, 116, 118],
#          [ 73,  73,  73, ..., 117, 117, 116],
#          ...,
#          [ 69,  67,  68, ...,  49,  51,  48],
#          [161, 156, 170, ...,  45,  48,  48],
#          [138, 130, 111, ...,  44,  44,  43]], dtype=uint8),
#   [0, 1]],
#  [array([[151, 146, 150, ..., 171, 171, 171],
#          [148, 151, 152, ..., 171, 171, 172],
#          [148, 151, 149, ..., 172, 173, 171],
#          ...,
#          [ 42,  30,  20, ...,  53,  64,  53],
#          [ 55,  43,  44, ...,  52,  57,  66],
#          [ 35,  42,  46, ...,  48,  53,  54]], dtype=uint8),
#   [1, 0]],
#  [array([[178, 180, 178, ...,  84,  58, 107],
#          [177, 179, 180, ..., 158,  83,  51],
#          [179, 179, 178, ..., 138,  99,  56],
#          ...,
#          [210, 209, 201, ...,  83,  78,  78],
#          [214, 216, 221, ...,  85,  83,  68],
#          [219, 226, 175, ...,  86,  86,  79]], dtype=uint8),
#   [0, 1]],
#  [array([[133, 138, 155, ..., 176, 176, 178],
#          [139, 135, 166, ..., 176, 174, 177],
#          [146, 138, 172, ..., 178, 175, 182],
#          ...,
#          [104,  99, 107, ..., 202, 206, 206],
#          [ 90,  96, 108, ..., 204, 207, 205],
#          [ 99, 100,  96, ..., 196, 201, 202]], dtype=uint8),
#   [1, 0]],
#  [array([[194, 170, 172, ..., 157, 155, 128],
#          [181, 160, 163, ..., 152, 146, 128],
#          [168, 154, 156, ..., 141, 135, 147],
#          ...,
#          [ 43,  49, 122, ...,  45,  63,  57],
#          [ 51,  56,  31, ...,  62,  69,  61],
#          [ 45,  48,  39, ...,  68,  79,  63]], dtype=uint8),
#   [1, 0]],
#  [array([[ 37,  11,  81, ...,  54,  58,  61],
#          [ 36,   9,  86, ...,  58,  57,  56],
#          [ 37,  25,  77, ...,  58,  54,  50],
#          ...,
#          [ 74,  82,  78, ...,  91, 103, 103],
#          [ 68,  65,  71, ...,  95,  97,  91],
#          [ 72,  75,  79, ...,  99,  98,  97]], dtype=uint8),
#   [0, 1]],
#  [array([[ 29,   1,   7, ...,  41,  41,  41],
#          [ 37,  35,  42, ...,  41,  41,  41],
#          [ 36,  37,  36, ...,  42,  42,  42],
#          ...,
#          [161, 163, 165, ..., 158, 158, 156],
#          [162, 164, 165, ..., 158, 157, 154],
#          [159, 162, 164, ..., 159, 156, 156]], dtype=uint8),
#   [1, 0]],
#  [array([[ 71, 174,  54, ...,  42,  44,  32],
#          [ 58, 111, 116, ...,  50,  49,  54],
#          [ 49,  41, 173, ...,  46,  46,  62],
#          ...,
#          [ 72,  63,  68, ...,  69,  74,  40],
#          [ 57,  67,  50, ...,  91,  67,  79],
#          [ 44,  40,  52, ...,  43,  34,  43]], dtype=uint8),
#   [0, 1]],
#  [array([[ 80,  80,  83, ...,  72,  70,  68],
#          [ 86,  83,  86, ...,  74,  72,  70],
#          [ 89,  88,  86, ...,  73,  73,  71],
#          ...,
#          [228, 218, 201, ...,  74,  60,  67],
#          [220, 220, 200, ...,  77,  61,  71],
#          [194, 202, 201, ...,  73,  55,  69]], dtype=uint8),
#   [0, 1]],
#  [array([[148, 146, 151, ..., 136, 139, 112],
#          [147, 125, 128, ..., 136, 132, 127],
#          [123, 137, 147, ..., 131, 142, 132],
#          ...,
#          [121, 122, 131, ..., 119, 111, 111],
#          [122, 130, 127, ..., 117, 120, 119],
#          [120, 125, 118, ..., 121, 117, 111]], dtype=uint8),
#   [0, 1]],
#  [array([[209, 211, 213, ..., 180, 180, 177],
#          [210, 211, 212, ..., 230, 204, 176],
#          [210, 211, 211, ..., 230, 234, 227],
#          ...,
#          [123, 123, 121, ..., 153, 164, 168],
#          [123, 128, 120, ..., 159, 157, 162],
#          [122, 116, 114, ..., 214, 150, 157]], dtype=uint8),
#   [1, 0]],
#  [array([[234, 232, 232, ...,  55,  50,  89],
#          [231, 231, 233, ...,  57,  54,  79],
#          [231, 232, 232, ...,  57,  67,  83],
#          ...,
#          [103, 106, 105, ...,  88,  92,  92],
#          [103, 113, 110, ..., 100,  91,  93],
#          [109, 115, 108, ...,  94,  87,  92]], dtype=uint8),
#   [0, 1]],
#  [array([[ 25,  26,  28, ..., 142, 145, 147],
#          [ 23,  25,  28, ..., 138, 144, 146],
#          [ 23,  26,  28, ..., 141, 142, 147],
#          ...,
#          [ 78,  93, 112, ...,  76, 114, 151],
#          [ 71,  69, 113, ...,  94,  75, 148],
#          [ 72,  76,  73, ...,  83,  87,  74]], dtype=uint8),
#   [1, 0]],
#  [array([[ 43, 184,  14, ...,  14, 171,  12],
#          [199, 142, 150, ...,  17,  17, 173],
#          [  8, 184, 189, ..., 185,  11,  20],
#          ...,
#          [194, 194, 193, ..., 208, 200, 191],
#          [193, 191, 191, ..., 200, 194, 187],
#          [188, 189, 189, ..., 195, 186, 180]], dtype=uint8),
#   [1, 0]],
#  [array([[ 73,  94, 105, ...,  69,  69,  60],
#          [ 66, 101,  96, ...,  60,  62,  58],
#          [ 69,  85, 102, ...,  66,  66,  64],
#          ...,
#          [ 24,  28,  27, ...,  76,  58,  54],
#          [ 25,  24,  27, ...,  66,  50,  49],
#          [ 29,  26,  27, ...,  49,  65,  59]], dtype=uint8),
#   [0, 1]],
#  [array([[ 89,  85,  81, ...,  68,  66,  63],
#          [ 79,  84,  83, ...,  66,  65,  62],
#          [ 82,  79,  79, ...,  66,  64,  56],
#          ...,
#          [104,  56,  57, ..., 149, 143, 146],
#          [206,  98, 137, ..., 147, 141, 135],
#          [179, 173, 143, ..., 130, 130, 132]], dtype=uint8),
#   [1, 0]],
#  [array([[ 47,  46,  49, ...,  74,  72,  73],
#          [ 50,  51,  51, ...,  74,  73,  74],
#          [ 50,  51,  54, ...,  74,  73,  77],
#          ...,
#          [ 33,  30,  42, ..., 102, 101,  99],
#          [ 33,  35,  35, ..., 100, 103, 101],
#          [ 32,  37,  35, ...,  98, 101,  99]], dtype=uint8),
#   [1, 0]],
#  [array([[ 49,  57,  68, ...,  55,  83,  71],
#          [ 52,  63,  72, ...,   7,  85,  75],
#          [ 54,  66,  78, ...,  81,  95,  79],
#          ...,
#          [ 94, 102, 114, ..., 129, 145, 139],
#          [103, 121, 130, ..., 161, 134, 142],
#          [115, 135, 129, ..., 201, 152,  81]], dtype=uint8),
#   [1, 0]],
#  [array([[114, 134, 201, ..., 174, 172, 160],
#          [141, 102, 185, ..., 156, 149, 148],
#          [180,  92, 123, ..., 101, 116, 103],
#          ...,
#          [168, 148, 163, ...,  89,  97,  93],
#          [139, 156, 150, ..., 107,  68,  98],
#          [142, 143, 172, ...,  62,  93,  96]], dtype=uint8),
#   [0, 1]],
#  [array([[ 23,  35,  49, ..., 245, 245, 246],
#          [ 39,  53, 116, ..., 244, 244, 244],
#          [ 61, 124, 121, ..., 238, 228, 243],
#          ...,
#          [149, 156, 164, ..., 187, 187, 198],
#          [139, 150, 159, ..., 197, 184, 196],
#          [153, 159, 154, ..., 191, 182, 190]], dtype=uint8),
#   [1, 0]],
#  [array([[255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          ...,
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255]], dtype=uint8),
#   [0, 1]],
#  [array([[100, 100, 102, ..., 128, 123, 114],
#          [ 96,  99, 105, ..., 124, 119,  86],
#          [ 94,  96, 102, ..., 118,  97, 121],
#          ...,
#          [ 96,  94,  94, ...,  72,  73,  76],
#          [ 92,  92,  94, ...,  70,  76,  73],
#          [ 94,  92,  91, ...,  70,  70,  70]], dtype=uint8),
#   [0, 1]],
#  [array([[162, 172, 194, ...,  11,  10,  11],
#          [161, 172, 188, ...,  11,   9,  10],
#          [161, 171, 180, ...,  10,  12,  10],
#          ...,
#          [195, 243, 241, ...,  23,  21,  24],
#          [229, 206, 246, ...,  66,  22,  25],
#          [235, 220, 231, ..., 130, 107, 118]], dtype=uint8),
#   [1, 0]],
#  [array([[ 57,  57,  48, ...,  36,  41,  38],
#          [162, 142,  80, ...,  35,  39,  40],
#          [ 73,  67,  58, ...,  30,  33,  33],
#          ...,
#          [166, 150, 213, ..., 110, 105, 103],
#          [168, 200, 218, ..., 110, 112, 106],
#          [183, 215, 219, ..., 112, 110, 110]], dtype=uint8),
#   [0, 1]],
#  [array([[ 33,  44,  54, ..., 134, 132, 132],
#          [153, 118, 131, ..., 134, 132, 131],
#          [ 81, 164, 141, ..., 134, 132, 131],
#          ...,
#          [ 50,  25,  22, ...,  96,  93,  81],
#          [ 22,  22,  31, ...,  79,  72,  72],
#          [ 18,  31,  42, ...,  63,  60,  56]], dtype=uint8),
#   [1, 0]],
#  [array([[254, 254, 254, ..., 254, 254, 254],
#          [254, 218, 252, ..., 254, 254, 254],
#          [253, 252, 157, ..., 254, 254, 254],
#          ...,
#          [ 97,  84, 142, ...,  76,  81,  75],
#          [106, 186, 166, ...,  87, 110,  71],
#          [167, 188, 178, ...,  92,  89,  92]], dtype=uint8),
#   [0, 1]],
#  [array([[ 62,  73, 115, ..., 183, 187, 186],
#          [106, 119, 129, ..., 186, 186, 187],
#          [117,  91, 128, ..., 186, 187, 188],
#          ...,
#          [137, 126, 114, ..., 163, 132, 130],
#          [125, 109,  91, ..., 160, 152, 132],
#          [107,  92,  89, ..., 161, 153, 141]], dtype=uint8),
#   [0, 1]],
#  [array([[179, 198, 182, ...,  52, 123,  38],
#          [171, 163, 153, ..., 134, 119,  68],
#          [130, 180, 141, ...,  46, 109,  42],
#          ...,
#          [251, 254, 254, ...,  66, 170, 225],
#          [ 62,  71, 138, ...,  77, 217, 242],
#          [ 63,  70,  72, ..., 232, 238, 231]], dtype=uint8),
#   [1, 0]],
#  [array([[142, 121, 110, ...,  99,  98, 101],
#          [127, 143, 136, ...,  99,  98,  98],
#          [112, 118, 118, ...,  99,  97,  99],
#          ...,
#          [225, 224, 220, ..., 245, 247, 247],
#          [222, 223, 221, ..., 246, 243, 247],
#          [226, 225, 222, ..., 248, 244, 248]], dtype=uint8),
#   [0, 1]],
#  [array([[ 68,  69,  73, ..., 150, 147, 141],
#          [ 63,  66,  73, ..., 151, 154, 151],
#          [ 62,  66,  68, ..., 160, 151, 137],
#          ...,
#          [ 97, 106, 123, ..., 124, 130, 138],
#          [ 97, 104, 118, ..., 106, 115, 126],
#          [107, 113,  92, ..., 135, 134, 134]], dtype=uint8),
#   [1, 0]],
#  [array([[ 28,  18,  28, ..., 115, 118, 118],
#          [ 30,  28,  15, ..., 117, 117, 120],
#          [ 32,  30,  31, ..., 116, 119, 120],
#          ...,
#          [ 63,  56,  43, ..., 116, 120, 123],
#          [ 60,  54,  43, ..., 118, 119, 121],
#          [ 61,  54,  42, ..., 116, 119, 123]], dtype=uint8),
#   [0, 1]],
#  [array([[  4,   6,   2, ...,  27,  26,  19],
#          [ 18,  25,  32, ..., 154, 144, 103],
#          [ 27,  28,  55, ..., 172, 158, 107],
#          ...,
#          [ 34,  72, 114, ..., 153,  66, 235],
#          [ 50,  22,  32, ..., 164,  78,  73],
#          [ 65,  76,  78, ...,  59,  92, 156]], dtype=uint8),
#   [1, 0]],
#  [array([[ 16,  21,  25, ..., 104, 110,  92],
#          [ 31,  14,  26, ..., 141,  86, 105],
#          [ 24,  39,  31, ...,  75, 107,  63],
#          ...,
#          [ 82, 155, 119, ..., 108,  71,  89],
#          [100, 125, 109, ..., 215,  90,  78],
#          [123, 112,  98, ...,  90, 128, 118]], dtype=uint8),
#   [0, 1]],
#  [array([[175, 182, 188, ..., 121, 121, 132],
#          [187, 188, 194, ..., 129, 124, 129],
#          [182, 184, 192, ..., 155, 140, 171],
#          ...,
#          [223, 230, 247, ..., 250, 204, 210],
#          [208, 240, 233, ..., 241, 231, 235],
#          [214, 209, 242, ..., 244, 230, 206]], dtype=uint8),
#   [1, 0]],
#  [array([[54, 60, 54, ..., 19, 18, 19],
#          [27, 28, 35, ..., 36, 30, 18],
#          [29, 32, 23, ..., 70, 42, 59],
#          ...,
#          [23, 25, 53, ..., 61, 67, 31],
#          [52, 57, 59, ..., 41, 40, 60],
#          [46, 56, 48, ..., 33, 33, 55]], dtype=uint8),
#   [1, 0]],
#  [array([[  7,   5,   5, ...,  11,  12,  16],
#          [ 11,   6,   7, ...,  13,  16,  16],
#          [  9,  11,   7, ...,  12,  13,  17],
#          ...,
#          [242, 247, 255, ..., 115, 121, 120],
#          [248, 253, 255, ..., 115, 107, 191],
#          [237, 254, 255, ..., 127, 161, 219]], dtype=uint8),
#   [1, 0]],
#  [array([[ 77,  73,  68, ...,  87,  90,  88],
#          [ 64,  68,  72, ...,  84,  78,  88],
#          [ 74,  71,  63, ..., 144, 145,  94],
#          ...,
#          [ 47,  49,  51, ...,  71,  62,  55],
#          [ 48,  51,  54, ...,  68,  65,  61],
# ...
#   [1, 0]],
#  [array([[160, 155, 151, ...,  74, 183, 152],
#          [142, 152, 144, ..., 109,  57, 158],
#          [157, 150, 209, ..., 130, 171, 114],
#          ...,
#          [ 24,  24,  19, ..., 153, 150, 157],
#          [ 26,  29,  26, ..., 157, 147, 156],
#          [ 28,  29,  28, ..., 159, 159, 153]], dtype=uint8),
#   [1, 0]],
#  [array([[  1,   1,   1, ...,  12,   7,  15],
#          [  1,   1,   0, ...,  16,  15,   8],
#          [  1,   1,   2, ...,  14,  13,   6],
#          ...,
#          [ 70,  77,  71, ...,   1,   2,   1],
#          [ 78,  84,  86, ...,   1,   1,   1],
#          [ 96, 112, 106, ...,   0,   1,   1]], dtype=uint8),
#   [0, 1]],
#  [array([[255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          ...,
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255]], dtype=uint8),
#   [0, 1]],
#  [array([[ 78,  69,  73, ...,  40,  28,  31],
#          [ 76,  82,  78, ...,  34,  27,  28],
#          [106, 111,  75, ...,  28,  24,  32],
#          ...,
#          [153, 144, 147, ..., 192, 200, 239],
#          [149, 149, 153, ..., 173, 187, 210],
#          [172, 170, 140, ..., 191, 203, 196]], dtype=uint8),
#   [1, 0]],
#  [array([[ 5, 29, 31, ..., 38, 37, 36],
#          [ 6, 30, 29, ..., 36, 37, 36],
#          [ 4, 29, 31, ..., 37, 38, 37],
#          ...,
#          [43, 55, 73, ..., 33, 30, 31],
#          [50, 46, 49, ..., 36, 32, 32],
#          [66, 57, 54, ..., 31, 33, 32]], dtype=uint8),
#   [1, 0]],
#  [array([[112, 111, 115, ..., 144, 144, 145],
#          [112, 110, 109, ..., 144, 144, 143],
#          [113, 112, 111, ..., 144, 144, 146],
#          ...,
#          [ 43,  48,  48, ..., 144, 144, 144],
#          [ 46,  48,  48, ..., 144, 144, 144],
#          [ 48,  48,  48, ..., 144, 144, 144]], dtype=uint8),
#   [0, 1]],
#  [array([[242, 245, 234, ..., 221, 199, 121],
#          [167, 204, 208, ..., 176, 109, 110],
#          [159, 210, 220, ...,  99, 106, 103],
#          ...,
#          [167, 168, 166, ..., 204, 197, 184],
#          [167, 169, 170, ..., 199, 193, 188],
#          [169, 175, 171, ..., 200, 190, 190]], dtype=uint8),
#   [0, 1]],
#  [array([[ 20,  21,  24, ..., 107, 123, 125],
#          [ 25,  21,  21, ...,  94, 113, 119],
#          [ 39,  28, 172, ...,  89, 108, 118],
#          ...,
#          [ 38,  47,  44, ...,  29,  32,  30],
#          [ 38,  41,  43, ...,  30,  32,  36],
#          [ 30,  42,  40, ...,  29,  28,  32]], dtype=uint8),
#   [0, 1]],
#  [array([[112, 146, 105, ..., 224, 172, 134],
#          [111, 153, 111, ..., 220, 167, 157],
#          [108, 155, 120, ..., 221, 147, 126],
#          ...,
#          [127, 188, 187, ..., 202, 215, 207],
#          [181, 179, 178, ..., 193, 206, 196],
#          [172, 172, 178, ..., 194, 201, 202]], dtype=uint8),
#   [0, 1]],
#  [array([[193, 193, 194, ..., 194, 194, 196],
#          [195, 194, 188, ..., 195, 192, 200],
#          [195, 187, 189, ..., 168, 195, 201],
#          ...,
#          [115, 116, 112, ...,  92,  94,  89],
#          [116, 112, 109, ..., 101,  98,  97],
#          [116, 113, 114, ...,  99,  99, 106]], dtype=uint8),
#   [1, 0]],
#  [array([[ 55, 149, 159, ..., 175, 173, 177],
#          [ 76,  70, 113, ..., 174, 174, 177],
#          [ 59,  76,  73, ..., 171, 176, 175],
#          ...,
#          [ 45,  43,  45, ..., 137, 144, 135],
#          [ 44,  44,  44, ..., 135, 130, 134],
#          [ 44,  44,  44, ..., 120, 132, 129]], dtype=uint8),
#   [0, 1]],
#  [array([[ 50,  54,  54, ...,  93, 103,  10],
#          [ 53,  55,  57, ...,  77, 104,  12],
#          [ 54,  55,  58, ...,  58, 107,  20],
#          ...,
#          [182, 193, 199, ...,  22,  13,  18],
#          [185, 200, 206, ...,  26,  23,  14],
#          [194, 198, 200, ...,  31,  22,  15]], dtype=uint8),
#   [1, 0]],
#  [array([[85, 86, 82, ..., 22, 46, 65],
#          [93, 84, 68, ..., 30, 47, 30],
#          [73, 73, 53, ..., 49, 35, 47],
#          ...,
#          [40, 37, 33, ..., 38, 33, 37],
#          [37, 39, 33, ..., 38, 34, 35],
#          [39, 31, 29, ..., 40, 38, 40]], dtype=uint8),
#   [0, 1]],
#  [array([[252, 254, 253, ..., 134, 133, 122],
#          [252, 254, 253, ..., 126, 133, 122],
#          [252, 254, 253, ..., 113, 138, 122],
#          ...,
#          [200, 208, 215, ..., 220, 211, 199],
#          [200, 207, 216, ..., 247, 234, 213],
#          [200, 207, 216, ..., 255, 250, 237]], dtype=uint8),
#   [1, 0]],
#  [array([[ 63,  69,  72, ...,  83, 110, 112],
#          [ 68,  65,  77, ...,  81,  75,  65],
#          [ 62,  73,  71, ...,  71,  62,  53],
#          ...,
#          [133, 129, 125, ..., 188, 123, 131],
#          [124, 125, 130, ...,  81, 142, 138],
#          [129, 128, 129, ..., 121, 138, 130]], dtype=uint8),
#   [1, 0]],
#  [array([[175, 212, 195, ...,  95,  71,  77],
#          [234, 199, 203, ...,  81,  33,  31],
#          [220, 201, 213, ...,  40,  34,  42],
#          ...,
#          [ 63,  67,  67, ...,   6,   7,   8],
#          [ 65,  66,  67, ...,   7,   8,   5],
#          [ 67,  68,  67, ...,  11,  14,   8]], dtype=uint8),
#   [1, 0]],
#  [array([[110, 128, 160, ..., 253, 254, 253],
#          [109, 107, 113, ..., 247, 249, 246],
#          [ 89, 101, 105, ..., 239, 238, 238],
#          ...,
#          [161, 184, 198, ..., 125,  38,  82],
#          [190, 188, 171, ...,  97,  29, 107],
#          [157, 185, 186, ...,  93,  36,  96]], dtype=uint8),
#   [1, 0]],
#  [array([[192, 160, 156, ...,  57,  75,  76],
#          [163, 158, 156, ...,  77,  81,  76],
#          [193, 161, 160, ...,  65,  75,  91],
#          ...,
#          [132, 187, 148, ..., 166, 162, 161],
#          [158, 152, 180, ..., 136, 133, 124],
#          [151, 171, 151, ...,  91,  73, 131]], dtype=uint8),
#   [1, 0]],
#  [array([[  9,   9,  10, ...,   1,   0,   3],
#          [ 11,  10,  11, ...,   3,   3,  43],
#          [ 13,  13,  12, ...,   3,   4,  37],
#          ...,
#          [ 43,  44,  48, ..., 215, 200, 112],
#          [ 44,  46,  38, ..., 130, 153,  96],
#          [ 46,  50,  47, ...,  81, 101, 131]], dtype=uint8),
#   [0, 1]],
#  [array([[ 88,  84, 106, ..., 139, 162, 192],
#          [212, 214, 217, ..., 136, 172, 195],
#          [212, 217, 221, ..., 132, 195, 185],
#          ...,
#          [ 84,  82,  83, ..., 234, 242, 234],
#          [ 89, 104, 107, ..., 209, 224, 213],
#          [ 88,  79,  99, ..., 223, 229, 223]], dtype=uint8),
#   [0, 1]],
#  [array([[226, 224, 227, ..., 225, 225, 224],
#          [217, 173, 175, ..., 166, 162, 214],
#          [219, 147, 100, ..., 106, 130, 214],
#          ...,
#          [224, 156, 127, ..., 105, 138, 219],
#          [221, 173, 177, ..., 163, 161, 217],
#          [225, 224, 224, ..., 221, 219, 221]], dtype=uint8),
#   [1, 0]],
#  [array([[ 99, 102, 104, ..., 160, 157, 142],
#          [102, 101, 102, ..., 160, 158, 141],
#          [103, 103, 101, ..., 158, 159, 142],
#          ...,
#          [ 15,  14,  11, ...,  21,  18,  18],
#          [ 10,  11,  12, ...,  25,  24,  20],
#          [  8,   8,   8, ...,  22,  24,  22]], dtype=uint8),
#   [0, 1]],
#  [array([[233, 204, 222, ..., 249, 242, 253],
#          [218, 248, 246, ..., 181, 164, 254],
#          [242, 145, 233, ..., 219, 250, 238],
#          ...,
#          [170, 172, 116, ..., 172, 118, 208],
#          [178, 189, 195, ..., 138, 159,  75],
#          [150,  68, 124, ..., 240,  84,  35]], dtype=uint8),
#   [0, 1]],
#  [array([[142, 138, 137, ...,  73,  85, 108],
#          [139, 139, 137, ...,  53,  69,  71],
#          [141, 137, 134, ...,  67,  58,  68],
#          ...,
#          [ 82,  82,  79, ...,  82, 109, 104],
#          [ 79,  78,  81, ...,  59,  86,  88],
#          [ 79,  80,  83, ...,  74,  75,  96]], dtype=uint8),
#   [1, 0]],
#  [array([[120, 125, 127, ..., 145, 136, 133],
#          [124, 126, 136, ..., 143, 143, 143],
#          [125, 131, 137, ..., 148, 150, 147],
#          ...,
#          [162, 173, 177, ..., 182, 177, 175],
#          [166, 167, 177, ..., 183, 182, 176],
#          [167, 172, 172, ..., 186, 178, 163]], dtype=uint8),
#   [1, 0]],
#  [array([[167, 166, 166, ..., 155, 151, 150],
#          [170, 165, 166, ..., 151, 151, 152],
#          [170, 164, 166, ..., 149, 150, 153],
#          ...,
#          [222, 217, 188, ..., 249, 252, 181],
#          [245, 214, 211, ..., 248, 249, 142],
#          [168, 233, 201, ..., 248, 236, 182]], dtype=uint8),
#   [1, 0]],
#  [array([[ 21,  26,  28, ...,  81, 145, 150],
#          [ 25,  32,  30, ..., 111, 147, 152],
#          [ 27,  27,  54, ..., 116, 156, 143],
#          ...,
#          [175, 183, 182, ..., 176, 164, 169],
#          [166, 175, 185, ..., 180, 172, 175],
#          [184, 188, 194, ..., 188, 178, 166]], dtype=uint8),
#   [0, 1]],
#  [array([[ 79,  86,  81, ...,  88, 107, 106],
#          [ 90,  73,  78, ..., 117,  97,  86],
#          [ 65,  64,  67, ..., 127, 108,  92],
#          ...,
#          [100,  79, 106, ...,  69,  73,  78],
#          [ 91,  90,  67, ...,  84,  73,  71],
#          [105,  80,  79, ...,  78,  84,  88]], dtype=uint8),
#   [0, 1]],
#  [array([[ 55,  56,  51, ...,  85,  82,  82],
#          [ 55,  55,  52, ...,  84,  82,  83],
#          [ 58,  57,  52, ...,  84,  82,  84],
#          ...,
#          [106, 107, 101, ...,  60,  68,  73],
#          [106, 106, 106, ...,  77,  96,  96],
#          [110,  95, 111, ...,  94,  98,  86]], dtype=uint8),
#   [1, 0]],
#  [array([[ 81,  50,  52, ...,  72,  69,  72],
#          [ 47,  10,  10, ...,  12,  10,  13],
#          [ 44,   8,   8, ...,   9,   8,  11],
#          ...,
#          [154, 139, 150, ..., 189, 181, 139],
#          [156, 138, 146, ..., 165, 148, 139],
#          [157, 138, 147, ..., 166, 144, 130]], dtype=uint8),
#   [0, 1]],
#  [array([[145, 154, 165, ...,  67,  70,  68],
#          [153, 168, 177, ...,  74,  76,  71],
#          [163, 175, 185, ...,  81,  80,  76],
#          ...,
#          [144, 144, 160, ...,  65,  80,  93],
#          [130, 151, 155, ...,  97, 105, 100],
#          [153, 163, 169, ..., 109, 120, 106]], dtype=uint8),
#   [1, 0]],
#  [array([[255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          ...,
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255]], dtype=uint8),
#   [0, 1]],
#  [array([[130,  72, 113, ...,  62,  40,  44],
#          [161,  91,  92, ...,  61,  52,  44],
#          [ 56,  50, 112, ...,  49,  38,  34],
#          ...,
#          [134, 139, 113, ...,  99, 120, 138],
#          [104, 155, 158, ..., 135, 143, 134],
#          [111, 123, 121, ..., 106, 123, 136]], dtype=uint8),
#   [0, 1]],
#  [array([[169, 127, 156, ..., 103, 160,  68],
#          [223, 111, 111, ...,  72,  67,  50],
#          [166,  74,  82, ...,  66, 106,  48],
#          ...,
#          [ 54,  62,  58, ...,  96, 126, 102],
#          [ 52,  51,  52, ...,  88,  87,  99],
#          [ 50,  51,  52, ..., 118, 142,  73]], dtype=uint8),
#   [0, 1]],
#  [array([[ 25,  27,  31, ...,  19,  20,  18],
#          [ 23,  24,  29, ...,  18,  19,  13],
#          [ 25,  20,  23, ...,  20,  23,  22],
#          ...,
#          [ 91, 137, 144, ...,  84,  75,  78],
#          [ 87, 133, 146, ...,  83,  80,  63],
#          [105, 130, 145, ...,  79,  83,  78]], dtype=uint8),
#   [0, 1]],
#  [array([[ 65,  64, 117, ..., 150, 198, 166],
#          [130, 119, 132, ..., 181, 172, 171],
#          [125, 127, 130, ..., 159, 174,  97],
#          ...,
#          [ 41,  34,  38, ..., 127, 124,  59],
#          [ 34,  37,  50, ..., 134, 167, 124],
#          [ 37,  29,  35, ..., 183, 228, 161]], dtype=uint8),
#   [1, 0]],
#  [array([[ 82,  78,  99, ...,  23, 170, 212],
#          [ 86,  80, 104, ...,  30, 195, 240],
#          [ 48,  75,  96, ..., 136, 193, 247],
#          ...,
#          [105,  19,  35, ...,  61,  59,  88],
#          [ 67,  20,  36, ...,  59,  60,  95],
#          [ 34,  22,  46, ...,  80,  87, 169]], dtype=uint8),
#   [1, 0]],
#  [array([[ 22,  15,  16, ...,  31,  34, 109],
#          [ 22,  24,  81, ..., 109, 100,  37],
#          [ 86,  91, 112, ...,  86,  44,  34],
#          ...,
#          [ 49,  38,  43, ..., 221, 150,  94],
#          [118,  56,  41, ..., 221, 198,  27],
#          [ 14,  52,  47, ..., 209, 196,  83]], dtype=uint8),
#   [1, 0]],
#  [array([[ 72,  74,  70, ...,  87,  85,  78],
#          [114,  69,  74, ...,  86,  80,  86],
#          [ 77,  74,  75, ...,  88,  91,  92],
#          ...,
#          [ 74,  80,  85, ...,  60,  69,  70],
#          [109,  96,  83, ...,  74,  69,  67],
#          [ 85,  90,  87, ...,  64,  53,  70]], dtype=uint8),
#   [0, 1]],
#  [array([[204, 208, 208, ...,  93,  91,  88],
#          [209, 213, 208, ...,  95,  91,  91],
#          [216, 212, 215, ...,  96,  95,  94],
#          ...,
#          [244, 247, 246, ...,  45,  36,  15],
#          [247, 247, 245, ..., 124, 112,  95],
#          [248, 245, 251, ..., 138, 115, 108]], dtype=uint8),
#   [1, 0]],
#  [array([[135, 144, 148, ..., 152, 144, 137],
#          [140, 149, 154, ..., 156, 150, 142],
#          [142, 148, 156, ..., 161, 153, 145],
#          ...,
#          [112, 120, 127, ...,  73,  95,  71],
#          [102, 111, 119, ...,  69,  78,  83],
#          [ 90, 100, 109, ..., 105,  79,  71]], dtype=uint8),
#   [1, 0]],
#  [array([[146, 152, 162, ..., 162, 151, 143],
#          [156, 163, 156, ..., 163, 149, 150],
#          [156, 158, 157, ..., 166, 163, 152],
#          ...,
#          [218, 228, 224, ..., 162, 165, 189],
#          [215, 216, 219, ..., 178, 187, 174],
#          [211, 211, 212, ...,  75, 174, 152]], dtype=uint8),
#   [0, 1]],
#  [array([[192, 183, 169, ...,  92, 112, 121],
#          [197, 188, 178, ...,  63, 115, 112],
#          [198, 182, 179, ...,  61, 122, 119],
#          ...,
#          [100,  93, 149, ..., 206, 223, 231],
#          [117, 213, 185, ..., 202, 228, 225],
#          [230, 229, 221, ..., 219, 214, 226]], dtype=uint8),
#   [1, 0]],
#  [array([[242, 243, 241, ...,  71,  66,  84],
#          [142, 121, 133, ...,  70,  59,  74],
#          [115, 132,  97, ...,  54,  63,  82],
#          ...,
#          [244,  58,  55, ...,  52,  72,  69],
#          [244,  72,  57, ..., 251, 252, 248],
#          [248, 251, 249, ..., 251, 251, 251]], dtype=uint8),
#   [0, 1]],
#  [array([[171, 186, 152, ...,  94, 166, 118],
#          [193, 209, 129, ...,  70, 179, 116],
#          [142, 146,  34, ..., 106, 159, 143],
#          ...,
#          [202, 202, 199, ..., 199, 193, 189],
#          [198, 199, 197, ..., 198, 196, 199],
#          [203, 198, 197, ..., 194, 194, 194]], dtype=uint8),
#   [0, 1]],
#  [array([[103, 154, 131, ...,  95, 104, 110],
#          [ 92, 171, 102, ...,  90, 106, 104],
#          [129, 178,  91, ...,  88, 107, 108],
#          ...,
#          [ 65,  75,  62, ...,  69,  54,  57],
#          [ 66,  78,  63, ...,  71,  47,  38],
#          [ 71,  80,  61, ...,  76,  47,  38]], dtype=uint8),
#   [1, 0]],
#  [array([[59, 54, 43, ...,  1,  0,  2],
#          [41, 54, 57, ...,  1,  1,  4],
#          [54, 58, 55, ..., 12,  6,  1],
#          ...,
#          [75, 65, 64, ..., 58, 55, 57],
#          [59, 65, 74, ..., 46, 56, 56],
#          [73, 72, 74, ..., 52, 52, 52]], dtype=uint8),
#   [0, 1]],
#  [array([[126, 126, 130, ...,  28,  24,  24],
#          [130, 134, 135, ...,  31,  29,  25],
#          [133, 135, 139, ...,  30,  28,  22],
#          ...,
#          [ 67,  60,  45, ...,  61,  55,  50],
#          [ 47,  56,  36, ...,  58,  57,  57],
#          [ 68,  52,  44, ...,  61,  52,  56]], dtype=uint8),
#   [1, 0]],
#  [array([[27, 28, 32, ..., 18, 24, 24],
#          [29, 26, 33, ..., 19, 21, 26],
#          [26, 28, 26, ..., 23, 26, 29],
#          ...,
#          [26, 27, 27, ..., 59, 56, 61],
#          [26, 33, 31, ..., 60, 53, 57],
#          [28, 57, 57, ..., 58, 57, 56]], dtype=uint8),
#   [0, 1]],
#  [array([[123, 154, 129, ..., 217, 217, 217],
#          [110, 155, 124, ..., 216, 217, 217],
#          [ 95, 149, 124, ..., 217, 217, 218],
#          ...,
#          [166, 170, 169, ..., 197, 198, 197],
#          [169, 165, 173, ..., 198, 187, 190],
#          [171, 170, 173, ..., 190, 186, 193]], dtype=uint8),
#   [1, 0]],
#  [array([[213, 209, 206, ..., 166, 152, 145],
#          [218, 217, 205, ..., 133, 106, 174],
#          [219, 215, 206, ..., 216, 171,  91],
#          ...,
#          [ 56,  54,  57, ..., 169, 179, 144],
#          [ 56,  55,  53, ..., 164, 165, 160],
#          [ 55,  48,  79, ..., 185, 162, 102]], dtype=uint8),
#   [1, 0]],
#  ...]

# %%
# split the training data into train and test, for testing while training
train = train_data_set[:-500]
train_test = train_data_set[-500:]

# %%
# split both into X and Y
X = np.array([i[0] for i in train]).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
print(X.shape)
Y = np.array([i[1] for i in train])
print(Y.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-28aac6373fc9> in <module>
#       1 # split both into X and Y
# ----> 2 X_test_set = np.array([i[0] for i in train]).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
#       3 print(X.shape)
#       4 Y = np.array([i[1] for i in train])
#       5 print(Y.shape)
#
# ValueError: cannot reshape array of size 61250000 into shape (50,50,3)

# %%
# split both into X and Y
X_test_set = np.array([i[0] for i in train_test]).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
Y_test_set = np.array([i[1] for i in train_test])
print(X_test_set.shape)
print(Y_test_set.shape)
